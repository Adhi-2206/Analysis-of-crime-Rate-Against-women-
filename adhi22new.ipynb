# %% [markdown]
# # CRIME RATE ANALYSIS AGAINST WOMEN FROM 2011-2021

# %% [markdown]
# # Understanding the data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('darkgrid')
plt.rcParams['font.size'] =15
plt.rcParams['figure.figsize']=(10,7)
plt.rcParams['figure.facecolor']='#FFE5B4'

# %%
data=pd.read_excel(r'C:\Users\ADITHYA\Downloads\factors of women-1.xlsx')

# %% [markdown]
# # Displaying tail and head (Data aquasiation)

# %%
data.head()
# Out:
#    S.NO             STATES Regional indicator  YEAR  RAPE  KIDNAP & ABDUCTION  \
# 0     1     Andhra Pradesh          Southern   2011  1442                1612
# 1     2  Arunachal Pradesh     North-Eastern   2011    42                  60
# 2     3              Assam     North-Eastern   2011  1700                3192
# 3     4              Bihar            Eastern  2011   934                3050
# 4     5       Chhattisgarh            Central  2011  1053                 365
#
#    DOWRY DEATHS  CRUETLY BY HUSBAND OR HIS RELATIVES  HUMAN TRAFFICKING  \
# 0           599                                13376                  0
# 1             0                                   18                  0
# 2           121                                 5246                  2
# 3          1413                                 2607                 10
# 4           104                                  834                  2
#
# ...

# %%
data.tail()
# Out:
#      S.NO       STATES Regional indicator  YEAR  RAPE  KIDNAP & ABDUCTION  \
# 391    32   D&N Haveli    Union Territory  2021  1250                4083
# 392    33  Daman & Diu    Union Territory  2021   315                 904
# 393    34     Delhi UT    Union Territory  2021     2                   1
# 394    35  Lakshadweep    Union Territory  2021     0                   0
# 395    36   Puducherry    Union Territory  2021     2                   0
#
#      DOWRY DEATHS  CRUETLY BY HUSBAND OR HIS RELATIVES  HUMAN TRAFFICKING  \
# 391           141                                 4731                 24
# 392            16                                  501                  2
# 393             0                                    9                  0
# 394             0                                    3                  0
# 395             2                                   12                  0
#
#      ASSAULT ON MODESTY  SEXUAL HARRASSMENT  IMORTAL TRAFFICKING  \
# ...

# %% [markdown]
# # Data Acquasuation

# %% [markdown]
# # Displaying types

# %%
data['STATES'].dtype
# Out:
# dtype('O')

# %%
data['Regional indicator'].dtype
# Out:
# dtype('O')

# %%
data['YEAR'].dtype
# Out:
# dtype('int64')

# %%
data['RAPE'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# # Size

# %%
#displaying length of datasets
len(data)
# Out:
# 396

# %%
#displaying the column details
len(data.columns)
# Out:
# 13

# %%
#displying the shape
data.shape
# Out:
# (396, 13)

# %%
#displaying the info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396 entries, 0 to 395
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   S.NO                                 396 non-null    int64
#  1   STATES                               396 non-null    object
#  2   Regional indicator                   396 non-null    object
#  3   YEAR                                 396 non-null    int64
#  4   RAPE                                 396 non-null    int64
#  5   KIDNAP & ABDUCTION                   396 non-null    int64
#  6   DOWRY DEATHS                         396 non-null    int64
#  7   CRUETLY BY HUSBAND OR HIS RELATIVES  396 non-null    int64
#  8   HUMAN TRAFFICKING                    396 non-null    int64
#  9   ASSAULT ON MODESTY                   396 non-null    int64
#  10  SEXUAL HARRASSMENT                   396 non-null    int64
# ...

# %% [markdown]
# # Null Data information

# %%
#checking whether the value contains null

data.isnull().sum()
# Out:
# S.NO                                   0
# STATES                                 0
# Regional indicator                     0
# YEAR                                   0
# RAPE                                   0
# KIDNAP & ABDUCTION                     0
# DOWRY DEATHS                           0
# CRUETLY BY HUSBAND OR HIS RELATIVES    0
# HUMAN TRAFFICKING                      0
# ASSAULT ON MODESTY                     0
# SEXUAL HARRASSMENT                     0
# IMORTAL TRAFFICKING                    0
# TOTAL CRIMES AGAINST WOMEN             0
# dtype: int64

# %% [markdown]
# # Data preparation and removing duplicates

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 391    False
# 392    False
# 393    False
# 394    False
# 395    False
# Length: 396, dtype: bool

# %% [markdown]
# # counting unique values

# %%
#displying column unique value
data.nunique()
# Out:
# S.NO                                    36
# STATES                                  36
# Regional indicator                       7
# YEAR                                    11
# RAPE                                   305
# KIDNAP & ABDUCTION                     306
# DOWRY DEATHS                           194
# CRUETLY BY HUSBAND OR HIS RELATIVES    292
# HUMAN TRAFFICKING                       66
# ASSAULT ON MODESTY                     301
# SEXUAL HARRASSMENT                     207
# IMORTAL TRAFFICKING                    119
# TOTAL CRIMES AGAINST WOMEN             366
# dtype: int64

# %%
#displying row unique value
data.nunique(axis=1)
# Out:
# 0      12
# 1       9
# 2      13
# 3      13
# 4      13
#        ..
# 391    13
# 392    13
# 393    10
# 394     8
# 395    10
# Length: 396, dtype: int64

# %% [markdown]
# # Renaming columns name

# %%
data_columns=['STATES','Regional indicator','YEAR','RAPE','KIDNAP & ABDUCTION','DOWRY DEATHS','CRUETLY BY HUSBAND OR HIS RELATIVES','HUMAN TRAFFICKING','ASSAULT ON MODESTY','SEXUAL HARRASSMENT','IMORTAL TRAFFICKING','TOTAL CRIMES AGAINST WOMEN']

# %%
#copy of the columns

data=data[data_columns].copy()

# %%
new_df=data.rename({'STATES':'states','Regional indicator':'regional_indicator','YEAR':'year','RAPE':'rape','KIDNAP & ABDUCTION':'kidnap & abduction','DOWRY DEATHS':'dowry_deaths','CRUETLY BY HUSBAND OR HIS RELATIVES':'cruetly_by_husband_or_his_relatives','HUMAN TRAFFICKING':'human_trafficking','ASSAULT ON MODESTY':'assault on modesty','SEXUAL HARRASSMENT':'sexual_harrssment','IMORTAL TRAFFICKING':'imortal_trafficking','TOTAL CRIMES AGAINST WOMEN':'total_crimes_against_women'},axis=1)

# %%
new_df.head()
# Out:
#               states regional_indicator  year  rape  kidnap & abduction  \
# 0     Andhra Pradesh          Southern   2011  1442                1612
# 1  Arunachal Pradesh     North-Eastern   2011    42                  60
# 2              Assam     North-Eastern   2011  1700                3192
# 3              Bihar            Eastern  2011   934                3050
# 4       Chhattisgarh            Central  2011  1053                 365
#
#    dowry_deaths  cruetly_by_husband_or_his_relatives  human_trafficking  \
# 0           599                                13376                  0
# 1             0                                   18                  0
# 2           121                                 5246                  2
# 3          1413                                 2607                 10
# 4           104                                  834                  2
#
#    assault on modesty  sexual_harrssment  imortal_trafficking  \
# ...

# %% [markdown]
# # Finding missing data And data preparation

# %%
new_df.isnull()
# Out:
#      states  regional_indicator   year   rape  kidnap & abduction  \
# 0     False               False  False  False               False
# 1     False               False  False  False               False
# 2     False               False  False  False               False
# 3     False               False  False  False               False
# 4     False               False  False  False               False
# ..      ...                 ...    ...    ...                 ...
# 391   False               False  False  False               False
# 392   False               False  False  False               False
# 393   False               False  False  False               False
# 394   False               False  False  False               False
# 395   False               False  False  False               False
#
#      dowry_deaths  cruetly_by_husband_or_his_relatives  human_trafficking  \
# 0           False                                False              False
# ...

# %%
new_df.notnull() #identfying through not null
# Out:
#      states  regional_indicator  year  rape  kidnap & abduction  dowry_deaths  \
# 0      True                True  True  True                True          True
# 1      True                True  True  True                True          True
# 2      True                True  True  True                True          True
# 3      True                True  True  True                True          True
# 4      True                True  True  True                True          True
# ..      ...                 ...   ...   ...                 ...           ...
# 391    True                True  True  True                True          True
# 392    True                True  True  True                True          True
# 393    True                True  True  True                True          True
# 394    True                True  True  True                True          True
# 395    True                True  True  True                True          True
#
# ...

# %%
#filling the missing values by 0
new_df.fillna(0)
# Out:
#                 states regional_indicator  year  rape  kidnap & abduction  \
# 0       Andhra Pradesh          Southern   2011  1442                1612
# 1    Arunachal Pradesh     North-Eastern   2011    42                  60
# 2                Assam     North-Eastern   2011  1700                3192
# 3                Bihar            Eastern  2011   934                3050
# 4         Chhattisgarh            Central  2011  1053                 365
# ..                 ...                ...   ...   ...                 ...
# 391         D&N Haveli    Union Territory  2021  1250                4083
# 392        Daman & Diu    Union Territory  2021   315                 904
# 393           Delhi UT    Union Territory  2021     2                   1
# 394        Lakshadweep    Union Territory  2021     0                   0
# 395         Puducherry    Union Territory  2021     2                   0
#
#      dowry_deaths  cruetly_by_husband_or_his_relatives  human_trafficking  \
# ...

# %%
#filling the null values with previous one
new_df.fillna(method ='pad')
# Out:
#                 states regional_indicator  year  rape  kidnap & abduction  \
# 0       Andhra Pradesh          Southern   2011  1442                1612
# 1    Arunachal Pradesh     North-Eastern   2011    42                  60
# 2                Assam     North-Eastern   2011  1700                3192
# 3                Bihar            Eastern  2011   934                3050
# 4         Chhattisgarh            Central  2011  1053                 365
# ..                 ...                ...   ...   ...                 ...
# 391         D&N Haveli    Union Territory  2021  1250                4083
# 392        Daman & Diu    Union Territory  2021   315                 904
# 393           Delhi UT    Union Territory  2021     2                   1
# 394        Lakshadweep    Union Territory  2021     0                   0
# 395         Puducherry    Union Territory  2021     2                   0
#
#      dowry_deaths  cruetly_by_husband_or_his_relatives  human_trafficking  \
# ...

# %%
 new_df.dropna()
# Out:
#                 states regional_indicator  year  rape  kidnap & abduction  \
# 0       Andhra Pradesh          Southern   2011  1442                1612
# 1    Arunachal Pradesh     North-Eastern   2011    42                  60
# 2                Assam     North-Eastern   2011  1700                3192
# 3                Bihar            Eastern  2011   934                3050
# 4         Chhattisgarh            Central  2011  1053                 365
# ..                 ...                ...   ...   ...                 ...
# 391         D&N Haveli    Union Territory  2021  1250                4083
# 392        Daman & Diu    Union Territory  2021   315                 904
# 393           Delhi UT    Union Territory  2021     2                   1
# 394        Lakshadweep    Union Territory  2021     0                   0
# 395         Puducherry    Union Territory  2021     2                   0
#
#      dowry_deaths  cruetly_by_husband_or_his_relatives  human_trafficking  \
# ...

# %% [markdown]
# # Data visulasiation

# %%
#plot against crimes in different per year

plt.rcParams['figure.figsize']=(15,7)
plt.title('Plot between zones and total crime against women')
sns.scatterplot(x=new_df.year,y=new_df.total_crimes_against_women,hue=new_df.regional_indicator,s=200);

plt.legend(loc ='upper left',fontsize ='10')
plt.xlabel('Years')
plt.ylabel('Crimes in numbers')
# Out:
# Text(0, 0.5, 'Crimes in numbers')

# %%
new_list=new_df.groupby('regional_indicator')['rape'].sum()
new_list
# Out:
# regional_indicator
# Central            119532
# Eastern             50384
# North-Eastern       32724
# Northern            71826
# Southern            52803
# Union Territory     16968
# Western              6603
# Name: rape, dtype: int64

# %%
#total rape cases in region
new_list.plot.pie(autopct='%1.1f%%')
plt.title('total rape case in regions')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
total_kidnap=new_df.groupby('regional_indicator')['kidnap & abduction'].sum()
print(total_kidnap)
# Out:
# regional_indicator
# Central            223364
# Eastern            138067
# North-Eastern       87245
# Northern            95141
# Southern            55178
# Union Territory     41569
# Western             15784
# Name: kidnap & abduction, dtype: int64

# %%
#region analysis of kidnap cases
total_kidnap.plot.pie(autopct='%1.1f%%')
plt.title('region analysis of kidnap cases  against women')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
#state vs total crimes
plt.rcParams['figure.figsize']=(12,8)
plt.title('states vs total crimes')
plt.ylabel('crime rates',fontsize=15)
plt.xticks(rotation=40,ha='right')
plt.bar(new_df.states,new_df.total_crimes_against_women)
# Out:
# <BarContainer object of 396 artists>

# %%
#analysis of crime throgh year wise
plt.rcParams['figure.figsize']=(12,6)
plt.title('anaysis of crimes through year wise')
plt.xlabel('year',fontsize=13)
plt.ylabel('total crimes',fontsize=13)
plt.xticks(rotation=30,ha='right')
plt.bar(new_df.staest,new_df.total_crimes_against_women)
# Out:
# <BarContainer object of 396 artists>

# %%
#analysis of crimes through regions
plt.rcParams['figure.figsize']=(12,6)
plt.title('anaysis of crimes through Regions')
plt.xlabel('regions',fontsize=13)
plt.ylabel('total crimes',fontsize=13)
plt.xticks(rotation=30,ha='right')
plt.bar(new_df.regional_indicator,new_df.total_crimes_against_women)
# Out:
# <BarContainer object of 396 artists>

# %%
#analysis of rape cases 
plt.rcParams['figure.figsize']=(12,6)
plt.title('anaysis of Rape cases from 2011-2021')
plt.xlabel('year',fontsize=13)
plt.ylabel('total crimes',fontsize=13)
plt.xticks(rotation=30,ha='right')
plt.bar(new_df.year,new_df.rape)
# Out:
# <BarContainer object of 396 artists>

# %%
plt.rcParams['figure.figsize']=(15,7)
plt.title('Plot between zones and total crime against women')
sns.scatterplot(x=new_df.year,y=new_df.dowry_deaths,hue=new_df.regional_indicator,s=200);

plt.legend(loc ='upper left',fontsize ='10')
plt.xlabel('Years')
plt.ylabel('Crimes in numbers')
# Out:
# Text(0, 0.5, 'Crimes in numbers')

# %%
#distplot
total=[new_df.total_crimes_against_women]
sns.distplot([total])
plt.show()
# Out:
# C:\Users\ADITHYA\anaconda2\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
states = new_df.groupby('states')['total_crimes_against_women'].sum()
states
# Out:
# states
# A & N Islands          1623
# Andhra Pradesh       224965
# Arunachal Pradesh      3431
# Assam                241995
# Bihar                161270
# Chandigarh             3764
# Chhattisgarh          66471
# D&N Haveli            24606
# Daman & Diu            7547
# Delhi UT             111898
# Goa                    3494
# Gujarat               98427
# Haryana              118878
# Himachal Pradesh      15143
# Jammu & Kashmir       44892
# Jharkhand             78019
# Karnataka            137835
# Kerala               153849
# Lakshadweep             106
# Madhya Pradesh       292679
# Maharashtra          251352
# Manipur                3718
# Meghalaya              4005
# Mizoram                1832
# Nagaland              57456
# Odisha               159776
# Puducherry             1162
# Punjab               117775
# Rajasthan            251344
# Sikkim                16123
# Tamil Nadu            94051
# Telangana             98268
# Tripura              116911
# ...

# %%
#sorting of values
new=states.sort_values()
new
# Out:
# states
# Lakshadweep             106
# Puducherry             1162
# A & N Islands          1623
# Mizoram                1832
# Arunachal Pradesh      3431
# Goa                    3494
# Manipur                3718
# Chandigarh             3764
# Meghalaya              4005
# Daman & Diu            7547
# Himachal Pradesh      15143
# Sikkim                16123
# D&N Haveli            24606
# Jammu & Kashmir       44892
# Nagaland              57456
# Chhattisgarh          66471
# Jharkhand             78019
# Uttarakhand           87843
# Tamil Nadu            94051
# Telangana             98268
# Gujarat               98427
# Delhi UT             111898
# Tripura              116911
# Punjab               117775
# Haryana              118878
# Karnataka            137835
# Kerala               153849
# Odisha               159776
# Bihar                161270
# Andhra Pradesh       224965
# Assam                241995
# Rajasthan            251344
# Maharashtra          251352
# ...

# %% [markdown]
# # top 10 crimes country

# %%
top_10=new.tail(10)
top_10
# Out:
# states
# Kerala            153849
# Odisha            159776
# Bihar             161270
# Andhra Pradesh    224965
# Assam             241995
# Rajasthan         251344
# Maharashtra       251352
# West Bengal       286023
# Madhya Pradesh    292679
# Uttar Pradesh     383596
# Name: total_crimes_against_women, dtype: int64

# %%
bot_10=new.head(10)
bot_10
# Out:
# states
# Lakshadweep           106
# Puducherry           1162
# A & N Islands        1623
# Mizoram              1832
# Arunachal Pradesh    3431
# Goa                  3494
# Manipur              3718
# Chandigarh           3764
# Meghalaya            4005
# Daman & Diu          7547
# Name: total_crimes_against_women, dtype: int64

# %% [markdown]
# # Data Wrangling and heat map

# %%
f,ax=plt.subplots(figsize=(12,10))
sns.heatmap(new_df.loc[:,['states' ,'regional_indicator','year', 'rape', 'kidnap & abduction', 'dowry_deaths','cruetly_by_husband_or_his_relatives','human_trafficking','assault on modesty','sexual_harrssment','imortal_trafficking','total_crimes_against_women']].corr(),
            annot=True,
            linecolor='r',
            fmt='.1f',
        
            ax=ax);
plt.show()

# %% [markdown]
# # predicting accuracy

# %%
new_df1=data.drop(['Regional indicator'],axis=1)
X = new_df1.copy()
y = X.pop('STATES')

# %%
# Splitting data into training and testing data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 100)

# %%
# How to Import the DecisionTreeClassifer Class
from sklearn.tree import DecisionTreeClassifier
DecisionTreeClassifier(
    
    criterion='gini', 
    splitter='best', 
    max_depth=None, 
    min_samples_split=2, 
    min_samples_leaf=1, 
    min_weight_fraction_leaf=0.0, 
    max_features=None, 
    random_state=None, 
    max_leaf_nodes=None, 
    min_impurity_decrease=0.0, 
    class_weight=None, 
    ccp_alpha=0.0
)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Making Predictions with Our Model
predictions = clf.predict(X_test)
print(predictions[:120])
# Out:
# ['Punjab' 'Gujarat' 'Tamil Nadu' 'A & N Islands' 'Telangana' 'Bihar'
#  'Arunachal Pradesh' 'Jharkhand' 'Arunachal Pradesh' 'Maharashtra'
#  'Himachal Pradesh' 'Chandigarh' 'Goa' 'D&N Haveli' 'Assam' 'Telangana'
#  'Bihar' 'Arunachal Pradesh' 'Jharkhand' 'Himachal Pradesh' 'Odisha'
#  'Himachal Pradesh' 'Kerala' 'Uttarakhand' 'A & N Islands'
#  'Madhya Pradesh' 'Jharkhand' 'Andhra Pradesh' 'Haryana' 'A & N Islands'
#  'Tripura' 'Rajasthan' 'Karnataka' 'Gujarat' 'Bihar' 'Arunachal Pradesh'
#  'Meghalaya' 'Tripura' 'Sikkim' 'Kerala' 'Chhattisgarh' 'West Bengal'
#  'Chandigarh' 'Tripura' 'Puducherry' 'Himachal Pradesh' 'Uttarakhand'
#  'Jammu & Kashmir' 'Punjab' 'Manipur' 'Odisha' 'Gujarat' 'West Bengal'
#  'Arunachal Pradesh' 'Nagaland' 'Tripura' 'West Bengal' 'D&N Haveli'
#  'Sikkim' 'Chhattisgarh' 'Manipur' 'Telangana' 'Tripura' 'Lakshadweep'
#  'Telangana' 'Telangana' 'Rajasthan' 'Jammu & Kashmir' 'Nagaland'
#  'Uttar Pradesh' 'Uttarakhand' 'Manipur' 'Madhya Pradesh' 'Assam'
# ...

# %%
# Measuring the accuracy of our model
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, predictions))
# Out:
# 0.494949494949495

# %%
sns.pairplot(data=data, hue='STATES')
plt.show()
